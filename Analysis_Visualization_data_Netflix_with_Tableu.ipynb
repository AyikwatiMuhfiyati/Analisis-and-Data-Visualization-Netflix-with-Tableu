# %%
# Menampilkan data
# Google Colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
#membuka file dengan pandas : Diabetes
netflix = pd.read_csv('/content/gdrive/MyDrive/Kuliah D4TI/Portofolio/Visualisasi Data/Visualization Data Netflix with Tableu/netflix.csv')

#menampilkan header data
(netflix).head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# melihat beberapa baris data
netflix[70:80]
# Out:
#    show_id     type                                      title  \
# 70     s71  TV Show                  Too Hot To Handle: Latino
# 71     s72    Movie                A StoryBots Space Adventure
# 72     s73  TV Show     Jack Whitehall: Travels with My Father
# 73     s74    Movie                               King of Boys
# 74     s75  TV Show  The World's Most Amazing Vacation Rentals
# 75     s76    Movie                     You vs. Wild: Out Cold
# 76     s77  TV Show                            Yowamushi Pedal
# 77     s78    Movie              Little Singham - Black Shadow
# 78     s79    Movie                             Tughlaq Durbar
# 79     s80    Movie                    Tughlaq Durbar (Telugu)
#
#                     director  \
# 70                       NaN
# 71           David A. Vargas
# 72                       NaN
# 73              Kemi Adetiba
# 74                       NaN
# 75                 Ben Simms
# 76                       NaN
# ...

# %%
#melihat beberapa kolom data
netflix.iloc[0:100, [3,4,5]]
# Out:
#            director                                               cast  \
# 0   Kirsten Johnson                                                NaN
# 1               NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2   Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3               NaN                                                NaN
# 4               NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ..              ...                                                ...
# 95              NaN                                    Michelle Buteau
# 96    Stephen Kijak  Ronnie Van Zandt, Gary Rossington, Allen Colli...
# 97              NaN  Jack Fisher, Tom Kenny, Amanda C. Miller, Kim ...
# 98              NaN  Antonio Aakeel, Chipo Chung, Simon Foster, Ter...
# 99              NaN  Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
#
#                           country
# 0                   United States
# 1                    South Africa
# ...

# %%
#Range seluruh data, fitur director, cast, country

netflix.iloc[:, [3,4,5]]
# Out:
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# 1                 NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                 NaN                                                NaN
# 4                 NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...               ...                                                ...
# 8802    David Fincher  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803              NaN                                                NaN
# 8804  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805     Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#             country
# 0     United States
# 1      South Africa
# 2               NaN
# ...

# %% [markdown]
# 2. Data Preparation

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
#cek ada missing value atau tidak
netflix.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#bersihkan file tersebut supaya tidak ada missing value
data_netflix = netflix.dropna()

# %%
data_netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
data_netflix
# Out:
#      show_id     type                          title             director  \
# 7         s8    Movie                        Sankofa         Haile Gerima
# 8         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 9        s10    Movie                   The Starling       Theodore Melfi
# 12       s13    Movie                   Je Suis Karl  Christian Schwochow
# 24       s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 8801   s8802    Movie                        Zinzana      Majid Al Ansari
# 8802   s8803    Movie                         Zodiac        David Fincher
# 8804   s8805    Movie                     Zombieland      Ruben Fleischer
# 8805   s8806    Movie                           Zoom         Peter Hewitt
# 8806   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
# Menyimpan DataFrame ke file CSV
data_netflix.to_csv('data_netflix_fix.csv', index=False)

# Mengunduh file CSV ke lokal
from google.colab import files
files.download('data_netflix_fix.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Visualisasi data menggunakan Tableu

# %% [markdown]
# https://public.tableau.com/views/NetflixVisualization_16892258861660/NetflixDashboard?:language=en-US&:display_count=n&:origin=viz_share_link

# %%
# %%HTML
#
# <div class='tableauPlaceholder' id='viz1689226989350' style='position: relative'><noscript><a href='#'><img alt='Netflix Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;5G&#47;5GH5MP634&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;5GH5MP634' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;5G&#47;5GH5MP634&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div> <script type='text/javascript'> var divElement = document.getElementById('viz1689226989350'); var vizElement = divElement.getElementsByTagName('object')[0]; if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='1027px';} var scriptElement = document.createElement('script');scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';vizElement.parentNode.insertBefore(scriptElement, vizElement); </script>
# Out:
# <div class='tableauPlaceholder' id='viz1689226989350' style='position: relative'><noscript><a href='#'><img alt='Netflix Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;5G&#47;5GH5MP634&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;5GH5MP634' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;5G&#47;5GH5MP634&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div> <script type='text/javascript'> var divElement = document.getElementB
# ...

# %% [markdown]
# <div class='tableauPlaceholder' id='viz1689226840311' style='position: relative'><noscript><a href='#'><img alt='Netflix Dashboard ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;8K&#47;8KTY4J5F7&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;8KTY4J5F7' /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;8K&#47;8KTY4J5F7&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /><param name='language' value='en-US' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1689226840311');                    var vizElement = divElement.getElementsByTagName('object')[0];                    if ( divElement.offsetWidth > 800 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else if ( divElement.offsetWidth > 500 ) { vizElement.style.width='1000px';vizElement.style.height='827px';} else { vizElement.style.width='100%';vizElement.style.height='1027px';}                     var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
